# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
iris_data=sns.load_dataset('iris')
df=sns.load_dataset('taxis')

# %%
sns.scatterplot(x=iris_data['sepal_length'],y=iris_data['petal_length'])
plt.show()

# %%
sns.scatterplot(x=iris_data['sepal_length'],y=iris_data['petal_length'],hue=iris_data['species'],pa)
plt.show()
# Out:
#   Cell In[26], line 1
#     sns.scatterplot(x=iris_data['sepal_length'],y=iris_data['petal_length'],hue=iris_data['species'],pa)
#                                                                                                        ^
# SyntaxError: positional argument follows keyword argument

# %%
sns.stripplot(x=iris_data['species'],y=iris_data['sepal_width'],palette=['r','g','y'])
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
sns.stripplot(x=df['payment'],y=df['tip'],pattle=['r','g'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 sns.stripplot(x=df['payment'],y=df['tip'],pattle=['r','g','b'])
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2107, in stripplot(data, x, y, hue, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2104 palette, hue_order = p._hue_backcompat(color, palette, hue_order)
#    2106 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
# -> 2107 color = _default_color(ax.scatter, hue, color, kwargs)
#    2108 edgecolor = p._complement_color(edgecolor, color, p._hue_map)
#    2110 kwargs.setdefault("zorder", 3)
#
# File ~\anaconda3\Lib\site-packages\seaborn\utils.py:105, in _default_color(method, hue, color, kws, saturation)
#      99 scout_size = max(
# ...

# %%
sns.lineplot(x=df['tip'],y=df['fare'],)
plt.show()

# %%
sns.lineplot(x=df['total'],y=df['fare'],)
plt.show()

# %%
sns.lineplot(x=df['tip'],y=df['fare'],hue=df['payment'],palette=['red','orange'])
plt.show()

# %%
sns.lineplot(x=df['total'],y=df['fare'],hue=df['payment'],palette=['red','orange'])
plt.show()

# %%
df[(df['payment']=='cash') & (df['tip']>0)]
# Out:
# Empty DataFrame
# Columns: [pickup, dropoff, passengers, distance, fare, tip, tolls, total, color, payment, pickup_zone, dropoff_zone, pickup_borough, dropoff_borough]
# Index: []

# %%
sns.lineplot(x=df['tip'],y=df['fare'],hue=df['payment'],palette=['green','yellow'])
plt.show()

# %%
df[['payment','color']].value_counts()
# Out:
# payment      color
# credit card  yellow    4000
# cash         yellow    1412
# credit card  green      577
# cash         green      400
# Name: count, dtype: int64

# %%
df['color'].value_counts()
# Out:
# color
# yellow    5451
# green      982
# Name: count, dtype: int64

# %%
df['payment'].value_counts()
# Out:
# payment
# credit card    4577
# cash           1812
# Name: count, dtype: int64

# %%
sns.countplot(x=df['payment'])
# Out:
# <Axes: xlabel='payment', ylabel='count'>

# %%
sns.countplot(x=df['payment'],hue=df['color'],palette=['lightgreen','violet'])
# Out:
# <Axes: xlabel='payment', ylabel='count'>

# %%
plt.figure(figsize=(18,21))
sns.countplot(x=df['payment'],hue=df['color'],palette=['lightgreen','violet'])
plt.show()

# %%
plt.figure(figsize=(18,21))
sns.countplot(x=df['payment'],hue=df['color'],palette=['lightgreen','violet'])
plt.xlabel('Payment Mode',fontsize=18)
plt.show()

# %%
plt.figure(figsize=(18,21))
sns.countplot(x=df['payment'],hue=df['color'],palette=['pink','violet'])
plt.xlabel('Payment Mode',fontsize=18,color='black')
plt.show()

# %%
plt.figure(figsize=(18,21))
sns.countplot(x=df['payment'],hue=df['color'],palette=['gold','black'])
plt.xlabel('Payment Mode',fontsize=18,color='black')
plt.ylabel('Ride Counts for taxis',fontsize=18)
plt.show()

# %%
plt.figure(figsize=(18,21))
sns.countplot(x=df['payment'],hue=df['color'],palette=['black','grey'])
plt.xlabel('Payment Mode',fontsize=18,color='black')
plt.ylabel('Ride Counts for taxis',fontsize=18)
plt.yticks(range(0,6000,1000))
plt.show()
